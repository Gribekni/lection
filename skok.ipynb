# %%
import spacy

# Загрузка модели (с автоустановкой при необходимости)
try:
    nlp = spacy.load('ru_core_news_sm')
except OSError:
    from spacy.cli import download
    download('ru_core_news_sm')
    nlp = spacy.load('ru_core_news_sm')

# Чтение файла
with open('/home/roman/Downloads/avidreaders.ru__rasskazy7.txt', 'r', encoding = 'utf-8') as f:
    text = f.read()

# Подсчёт предложений
doc = nlp(text)
num_sents = len(list(doc.sents))

print(f"В тексте {num_sents} предложений.")
# Out:
# В тексте 2270 предложений.
